# %%
import pandas as pd

# %%
combined_data = pd.read_parquet("../combined_data/combined_data.parquet")
combined_data.head()
# Out:
#                       T_REC        USFLUX    MEANGAM     MEANGBT     MEANGBZ  \
# 0 2010-05-01 00:00:00+00:00           NaN        NaN         NaN         NaN
# 1 2010-05-01 00:12:00+00:00  1.439345e+21  32.159885  137.783195  137.832428
# 2 2010-05-01 00:24:00+00:00  1.488903e+21  32.006564  138.032814  137.932202
# 3 2010-05-01 00:36:00+00:00  1.495132e+21  32.489844  136.413847  136.048735
# 4 2010-05-01 00:48:00+00:00  1.566065e+21  31.843583  136.656334  136.326496
#
#      MEANGBH   MEANJZD       TOTUSJZ   MEANALP   MEANJZH  ...          NPIX  \
# 0        NaN       NaN           NaN       NaN       NaN  ...           NaN
# 1  59.383249  0.528793  2.065877e+12  0.001307 -0.000677  ...  21385.121136
# 2  58.588763  0.355526  2.096785e+12  0.001291 -0.000588  ...  22631.582458
# 3  59.049505  0.317466  2.190448e+12 -0.001002 -0.001128  ...  23156.134658
# 4  58.237536  0.342064  2.305668e+12 -0.000914 -0.000872  ...  24186.736691
#
# ...

# %%
combined_data.dtypes
# Out:
# T_REC                          datetime64[ns, UTC]
# USFLUX                                     float64
# MEANGAM                                    float64
# MEANGBT                                    float64
# MEANGBZ                                    float64
# MEANGBH                                    float64
# MEANJZD                                    float64
# TOTUSJZ                                    float64
# MEANALP                                    float64
# MEANJZH                                    float64
# TOTUSJH                                    float64
# ABSNJZH                                    float64
# SAVNCPP                                    float64
# MEANPOT                                    float64
# TOTPOT                                     float64
# MEANSHR                                    float64
# SHRGT45                                    float64
# NPIX                                       float64
# ...
